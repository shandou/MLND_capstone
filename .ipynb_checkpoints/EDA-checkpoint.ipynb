# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import sys
import os
import random
import gc
import subprocess
import pprint

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('./stylelib/custom.mplstyle')

# %% [markdown]
# ## Extract a random sample 1% of the original size

# %%
# %%time
raw_csv = './data/train.csv'
sample_csv = './data/train_sample.csv'
need_to_sample = False

if need_to_sample:
    result = subprocess.check_output('wc -l {}'.format(raw_csv), shell=True)
    nlines_total = int(result.split()[0])
    nlines_sample = int(0.01 * nlines_total)
    subprocess.call('head -1 {} > {}'.format(raw_csv, sample_csv), shell=True)
    subprocess.call('gshuf -n {} {} >> {}'.format(nlines_sample, raw_csv, sample_csv), shell=True)
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.06 µs

# %%
print(nlines_total, nlines_sample)
# Out:
# 184903891 1849038

# %%
# Load sampled csv into pandas dataframe, sort by click time (and reset index)
df = pd.read_csv(
    sample_csv, parse_dates=['click_time', 'attributed_time']
).sort_values(by='click_time').reset_index()

# %%
df.head()
# Out:
#      index      ip  app  device  os  channel          click_time  \
# 0  1333717  143257    3       1  15      379 2017-11-06 15:41:21
# 1  1302954  186555    3       1  13      379 2017-11-06 15:54:57
# 2  1194716  119289    3       1  13      379 2017-11-06 15:57:20
# 3  1303079   62129   12       1  13      245 2017-11-06 16:00:00
# 4   553988    2895    9       2  58      244 2017-11-06 16:00:00
#
#   attributed_time  is_attributed
# 0             NaT              0
# 1             NaT              0
# 2             NaT              0
# 3             NaT              0
# 4             NaT              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1849038 entries, 0 to 1849037
# Data columns (total 9 columns):
# index              int64
# ip                 int64
# app                int64
# device             int64
# os                 int64
# channel            int64
# click_time         datetime64[ns]
# attributed_time    datetime64[ns]
# is_attributed      int64
# dtypes: datetime64[ns](2), int64(7)
# memory usage: 127.0 MB

# %%
for col in ['click_time', 'attributed_time']:
    df[col] = pd.DatetimeIndex(df[col]).tz_localize('utc').tz_convert('Asia/Shanghai')

# %%
df['delta_time_click_vs_attr'] = (df['attributed_time'] - df['click_time']).dt.total_seconds()
df['delta_time_click_vs_attr'].describe()
# Out:
# count     4590.000000
# mean      5232.352941
# std      10738.269042
# min          0.000000
# 25%         57.000000
# 50%        301.000000
# 75%       4753.500000
# max      80089.000000
# Name: delta_time_click_vs_attr, dtype: float64

# %%
df['click_hour'] = df['click_time'].dt.hour
df['attr_hour'] = df['attributed_time'].dt.hour
df.head()
# Out:
#      index      ip  app  device  os  channel          click_time  \
# 0  1333717  143257    3       1  15      379 2017-11-06 15:41:21
# 1  1302954  186555    3       1  13      379 2017-11-06 15:54:57
# 2  1194716  119289    3       1  13      379 2017-11-06 15:57:20
# 3  1303079   62129   12       1  13      245 2017-11-06 16:00:00
# 4   553988    2895    9       2  58      244 2017-11-06 16:00:00
#
#   attributed_time  is_attributed  click_hour  attr_hour
# 0             NaT              0          15        NaN
# 1             NaT              0          15        NaN
# 2             NaT              0          15        NaN
# 3             NaT              0          16        NaN
# 4             NaT              0          16        NaN

# %%
ft2check = list(
    set(df.columns) ^ set(['click_time', 'attributed_time', 'is_attributed'])
)

# %%
df_unique = pd.DataFrame(df[ft2check].nunique()).T
df_unique
# Out:
#       ip  attr_hour  channel  device   os  app    index  click_hour
# 0  96409         24      175     609  218  324  1849038          24

# %%
hist_params = dict(bins=24, edgecolor='w', alpha=0.5)
no_params = dict(facecolor='lightcoral', label='No download')
yes_params = dict(facecolor='green', label='Yes download')
fig, ax = plt.subplots()
metric = 'click_hour'
ax.hist(df[df['is_attributed'] == 0][metric], **hist_params, **no_params)
ax.hist(df[df['is_attributed'] == 1][metric], **hist_params, **yes_params)
ax.legend(loc=4)
ax.set(
    yscale='log', xlabel='Hour of the day (Shanghai time)', ylabel='Count'
)
plt.show();

# %%
attr_ref = 'ip'
attr_list = ['click_hour', 'os', 'device', 'channel', 'app']
df_engineered = df.copy()

df.groupby(['ip', 'os']).count()['is_attributed'].reset_index().head()
# Out:
#    ip  os  is_attributed
# 0   6  13              2
# 1   6  18              1
# 2   6  19              4
# 3   6  20              1
# 4   6  23              2

# %%
import itertools
bla = []
for i in range(2, len(attr_list)):
    bla.append(list(itertools.combinations(attr_list, i)))
combination_list = list(itertools.chain(*bla))

# %%
for attr_other in combination_list:
    print(attr_other)
    tag = '-'.join(attr_other)
    print(tag)
    group_metric = [attr_ref] + list(attr_other)
    df_temp = df.groupby(group_metric).count()['is_attributed']
    df_temp = df_temp.reset_index().rename(columns={'is_attributed' : 'count_ip-{}'.format(tag)})
    df_summary = df.merge(df_temp, how='outer', on=group_metric)
    df_engineered['count_ip-by-{}'.format(tag)] = df_summary['count_ip-{}'.format(tag)]
# Out:
# ('click_hour', 'os')
# click_hour-os
# ('click_hour', 'device')
# click_hour-device
# ('click_hour', 'channel')
# click_hour-channel
# ('click_hour', 'app')
# click_hour-app
# ('os', 'device')
# os-device
# ('os', 'channel')
# os-channel
# ('os', 'app')
# os-app
# ('device', 'channel')
# device-channel
# ('device', 'app')
# device-app
# ('channel', 'app')
# channel-app
# ('click_hour', 'os', 'device')
# click_hour-os-device
# ('click_hour', 'os', 'channel')
# click_hour-os-channel
# ('click_hour', 'os', 'app')
# click_hour-os-app
# ('click_hour', 'device', 'channel')
# click_hour-device-channel
# ('click_hour', 'device', 'app')
# click_hour-device-app
# ('click_hour', 'channel', 'app')
# click_hour-channel-app
# ('os', 'device', 'channel')
# os-device-channel
# ('os', 'device', 'app')
# os-device-app
# ('os', 'channel', 'app')
# os-channel-app
# ('device', 'channel', 'app')
# device-channel-app
# ('click_hour', 'os', 'device', 'channel')
# click_hour-os-device-channel
# ('click_hour', 'os', 'device', 'app')
# click_hour-os-device-app
# ('click_hour', 'os', 'channel', 'app')
# click_hour-os-channel-app
# ('click_hour', 'device', 'channel', 'app')
# click_hour-device-channel-app
# ('os', 'device', 'channel', 'app')
# os-device-channel-app

# %%
df_engineered.head()
# Out:
#      index      ip  app  device  os  channel          click_time  \
# 0  1333717  143257    3       1  15      379 2017-11-06 15:41:21
# 1  1302954  186555    3       1  13      379 2017-11-06 15:54:57
# 2  1194716  119289    3       1  13      379 2017-11-06 15:57:20
# 3  1303079   62129   12       1  13      245 2017-11-06 16:00:00
# 4   553988    2895    9       2  58      244 2017-11-06 16:00:00
#
#   attributed_time  is_attributed  click_hour  \
# 0             NaT              0          15
# 1             NaT              0          15
# 2             NaT              0          15
# 3             NaT              0          16
# 4             NaT              0          16
#
#                  ...                  count_ip-by-click_hour-channel-app  \
# 0                ...                                                   1
# 1                ...                                                   1
# 2                ...                                                   2
# 3                ...                                                   2
# 4                ...                                                   2
#
#    count_ip-by-os-device-channel  count_ip-by-os-device-app  \
# 0                              1                          1
# 1                              1                          1
# 2                              6                         44
# 3                              6                         44
# 4                              6                         44
#
#    count_ip-by-os-channel-app  count_ip-by-device-channel-app  \
# 0                           1                               1
# 1                           1                               1
# 2                           2                               4
# 3                           2                               4
# 4                           2                               4
#
#    count_ip-by-click_hour-os-device-channel  \
# 0                                         1
# 1                                         1
# 2                                         2
# 3                                         2
# 4                                         1
#
#    count_ip-by-click_hour-os-device-app  \
# 0                                     1
# 1                                     1
# 2                                     4
# 3                                     4
# 4                                     4
#
#    count_ip-by-click_hour-os-channel-app  \
# 0                                      1
# 1                                      1
# 2                                      1
# 3                                      1
# 4                                      1
#
#    count_ip-by-click_hour-device-channel-app  \
# 0                                          1
# 1                                          1
# 2                                          2
# 3                                          2
# 4                                          2
#
#    count_ip-by-os-device-channel-app
# 0                                  1
# 1                                  1
# 2                                  2
# 3                                  2
# 4                                  2
#
# [5 rows x 45 columns]

# %%
metric_list = [x for x in df_engineered.columns if 'count' in x]
metric_list
# Out:
# ['count_ip-by-click_hour',
#  'count_ip-by-os',
#  'count_ip-by-device',
#  'count_ip-by-channel',
#  'count_ip-by-app',
#  "count_ip-by-('click_hour', 'os')",
#  "count_ip-by-('click_hour', 'device')",
#  "count_ip-by-('click_hour', 'channel')",
#  "count_ip-by-('click_hour', 'app')",
#  'count_ip-by-click_hour-os',
#  'count_ip-by-click_hour-device',
#  'count_ip-by-click_hour-channel',
#  'count_ip-by-click_hour-app',
#  'count_ip-by-os-device',
#  'count_ip-by-os-channel',
#  'count_ip-by-os-app',
#  'count_ip-by-device-channel',
#  'count_ip-by-device-app',
#  'count_ip-by-channel-app',
#  'count_ip-by-click_hour-os-device',
#  'count_ip-by-click_hour-os-channel',
#  'count_ip-by-click_hour-os-app',
#  'count_ip-by-click_hour-device-channel',
#  'count_ip-by-click_hour-device-app',
#  'count_ip-by-click_hour-channel-app',
#  'count_ip-by-os-device-channel',
#  'count_ip-by-os-device-app',
#  'count_ip-by-os-channel-app',
#  'count_ip-by-device-channel-app',
#  'count_ip-by-click_hour-os-device-channel',
#  'count_ip-by-click_hour-os-device-app',
#  'count_ip-by-click_hour-os-channel-app',
#  'count_ip-by-click_hour-device-channel-app',
#  'count_ip-by-os-device-channel-app']

# %%
def display(metric):
    fig, ax = plt.subplots()
    ax.hist(
        df_engineered[df_engineered['is_attributed'] == 0][metric], **hist_params, **no_params
    )
    ax.hist(
        df_engineered[df_engineered['is_attributed'] == 1][metric], **hist_params, **yes_params
    )
    ax.set(yscale='log')
    plt.show();

# %%
for metric in metric_list:
    display(metric)
